# %%
import json

with open("/projectnb/sparkgrp/ml-bpl-rag-data-subset/data/raw/out_1_329.json", "r") as f:
    data1 = json.load(f)

with open("/projectnb/sparkgrp/ml-bpl-rag-data-subset/data/raw/out_330_658.json", "r") as f:
    data2 = json.load(f)

all_data = data1 + data2

print(f"Loaded {len(all_data)} records")
print(all_data[0])
# Out:
# Running cells with 'env (Python 3.12.11)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /projectnb/sparkgrp/ml-bpl-rag-data-subset/env ipykernel --update-deps --force-reinstall'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from datasets import Dataset
#       2 from ragas.metrics import faithfulness, answer_relevance
#       3 from ragas import evaluate
#
# ModuleNotFoundError: No module named 'datasets'
