# %%
from datasets import load_dataset
dataset = load_dataset("csv", data_files="sample_queries.csv")["train"]

# %%
import os
assert os.getenv("OPENAI_API_KEY")

# %%
from ragas.metrics import answer_relevancy, faithfulness, context_recall, context_precision 
from ragas.llms import LangchainLLMWrapper
from langchain_openai import ChatOpenAI

# %%
llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o-mini", temperature=0))
# Out:
# /scratch/374271.1.ood/ipykernel_2302618/3231848894.py:1: DeprecationWarning: LangchainLLMWrapper is deprecated and will be removed in a future version. Use the modern LLM providers instead: from ragas.llms.base import llm_factory; llm = llm_factory('gpt-4o-mini') or from ragas.llms.base import instructor_llm_factory; llm = instructor_llm_factory('openai', client=openai_client)
#   llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o-mini", temperature=0))

# %%
print(dataset[0]["contexts"], type(dataset[0]["contexts"]))        # should be list
print(dataset[0]["ground_truths"], type(dataset[0]["ground_truths"]))
# Out:
# ['The Super Bowl....season since 1966,' , 'replacing the NFL...in February.'] <class 'str'>
# The first superbowl was held on January 15, 1967. <class 'str'>

# %%
from ragas import evaluate
result = evaluate(
    dataset=dataset,
    metrics=[context_precision, faithfulness, answer_relevancy, context_recall],
    llm=llm,
    column_map={
        "question": "question",
        "contexts": "contexts",
        "answer": "answer",
        "ground_truth": "ground_truths"
    }
)
result
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[25], line 2
#       1 from ragas import evaluate
# ----> 2 result = evaluate(
#       3     dataset=dataset,
#       4     metrics=[context_precision, faithfulness, answer_relevancy, context_recall],
#       5     llm=llm,
#       6     column_map={
#       7         "question": "question",
#       8         "contexts": "contexts",
#       9         "answer": "answer",
#      10         "ground_truth": "ground_truths"
#      11     }
#      12 )
#      13 result
#
# File ~/.local/lib/python3.12/site-packages/ragas/_analytics.py:277, in track_was_completed.<locals>.wrapper(*args, **kwargs)
#     274 @wraps(func)
#     275 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     276     track(IsCompleteEvent(event_type=func.__name__, is_completed=False))
# --> 277     result = func(*args, **kwargs)
# ...
